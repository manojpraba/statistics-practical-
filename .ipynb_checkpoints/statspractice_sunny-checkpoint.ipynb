# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

data_copy=data.copy()

# %%
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
sns.boxplot(data_copy)
# Out:
# <Axes: >

# %%
data_copy.append(179)
data_copy.append(210)
data_copy.append(290)

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Right skewed data

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %% [markdown]
# ##Left skwed data

# %%
data_copy2=data.copy()

# %%
data_copy2.insert(0,-10)

# %%
data_copy2
# Out:
# [-10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(2,-70)

# %%
data_copy2
# Out:
# [-12, -10, -70, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
df= pd.read_csv('C:\jupiter\data\data\iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.histplot(df['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.histplot(df['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import numpy as np
mu=0.5
sigma=0.2
sns.histplot(np.random.normal(mu,sigma,1000),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Lognormal distributed data

# %%
sns.histplot(np.random.lognormal(3.0,1.0,1000),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# if log finction is applied it converted into normal distribution

# %%
lognormal=np.random.lognormal(3.0,1.0,1000)

# %%
sns.histplot(np.log(lognormal),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# QQ - plot

# %%
import matplotlib.pyplot
import scipy.stats as stat
import pylab

def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(lognormal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 plot_data(lognormal)
#
# Cell In[53], line 6, in plot_data(sample)
#       5 def plot_data(sample):
# ----> 6     plt.figure(figsize=(10,6))
#       7     plot.subplot(1,2,1)
#       8     sns.histplot(sample,kde=True)
#
# NameError: name 'plt' is not defined
