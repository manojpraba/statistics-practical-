# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

data_copy=data.copy()

import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.append(209)

# %%
data_copy.append(290)

# %%
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy2=data.copy()

# %%
data_copy2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0,-10)

# %%
data_copy2.insert(0,-75)

# %%
data_copy2
# Out:
# [-75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
data2=pd.read_csv('C:\jupiter\data\data\iris.csv')

# %%
data2.head(1).T
# Out:
#                    0
# sepal_length     5.1
# sepal_width      3.5
# petal_length     1.4
# petal_width      0.2
# species       setosa

# %%
sns.histplot(data2['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data2['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data2['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data2['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import numpy as np
normal_distribution = np.random.normal(0.5,0.2,1000)

# %%
log_normal=np.random.lognormal(0.5,0.2,1000)

# %%
sns.histplot(log_normal,kde=True)
# Out:
# <Axes: ylabel='Count'>
